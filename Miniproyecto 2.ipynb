# %% [markdown]
# # Miniproyecto 2

# %% [markdown]
# ## Ejercicio 1 - Función acumulada ponderada

# %% [markdown]
# Se adjunta la imagen en los comentarios sobre la solución.

# %% [markdown]
# ## Ejercicio 2 – Función acumulada ponderada

# %%
import matplotlib.pyplot as plt
import numpy as np
import operator

# %% [markdown]
# ### Variable discreta

# %% [markdown]
# Sea X, una variable aleatoria, el # de caras en 3 lanzamientos de una moneda no cargada, su función de masa sería la siguiente:

# %%
funcion_de_masa = {
    0: 1/8, # 0 caras con probabilidad de 1/8
    1: 3/8, # 1 caras con probabilidad de 3/8
    2: 3/8, # 2 caras con probabilidad de 3/8
    3: 1/8  # 3 caras con probabilidad de 1/8
}

# %%
plt.bar(funcion_de_masa.keys(), funcion_de_masa.values(), color='g', edgecolor='black', linewidth=1)
plt.ylim((0, 1))
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ### Variable continua

# %%
funcion_de_masa = {
    (0, operator.lt): 1/10,       # x < 0: 0
    (1, operator.lt): 3/10,     # 0 <= x < 1: 1/2
    (2, operator.lt): 2/10,    # 1 <= x < 2: 1/10
    (3, operator.lt): (0.5)/10,     # 2 <= x < 3: 1/5
    (4, operator.lt): (0.5)/10,    # 3 <= x < 4: 1/10
    (4, operator.ge): 3/10     # x >= 4: 1/10
}

# %%
numeros = np.arange(-10, 10, 1)

# %%
xs = []
ys = []
for num in numeros:
    for key, value in funcion_de_masa.items():
        if key[1](num, key[0]):
            xs.append(num)
            ys.append(value)
            break

# %%
plt.bar(xs, ys, color='g', edgecolor='black', linewidth=1)
plt.ylim((0, 1))
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ## Ejercicio 3 - Valor presente Neto

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def distribucion_normal(media, desviacion_standar):
    return np.random.normal(media, desviacion_standar)

def distribucion_uniforme(media, desviacion_standar):
    return np.random.uniform(media - desviacion_standar, media + desviacion_standar)

def vpn(flujo, tiempo, tasa):
    if tiempo == 0:
        return flujo
    return flujo / (1 + tasa)**tiempo

# %%
proyecto_hotel = [
    (-800, 0, distribucion_uniforme),
    (-800, 50, distribucion_normal),
    (-800, 100, distribucion_normal),
    (-700, 150, distribucion_normal),
    (300, 200, distribucion_normal), 
    (400, 200, distribucion_normal),
    (500, 200, distribucion_normal),
    (200, 8440, distribucion_uniforme)
]

# %%
proyecto_centrocomercial = [
    (-900, 0, distribucion_uniforme),
    (-600, 50, distribucion_normal),
    (-200, 50, distribucion_normal),
    (-600, 100, distribucion_normal),
    (250, 150, distribucion_normal), 
    (350, 150, distribucion_normal),
    (400, 150, distribucion_normal),
    (1600, 6000, distribucion_uniforme)
]

# %%
r = 0.10

# %% [markdown]
# ### 100 iteraciones

# %%
N = 100

# %%
hotel = 0
centro_comercial = 0
for i in range(N):
    valor_presente_hotel = 0
    for i in range(len(proyecto_hotel)):
        c = proyecto_hotel[i][2](proyecto_hotel[i][0], proyecto_hotel[i][1])
        valor_presente_hotel += vpn(c, i, r)

    valor_presente_centrocomercial = 0
    for i in range(len(proyecto_centrocomercial)):
        c = proyecto_centrocomercial[i][2](proyecto_centrocomercial[i][0], proyecto_centrocomercial[i][1])
        valor_presente_centrocomercial += vpn(c, i, r)

    if valor_presente_hotel > valor_presente_centrocomercial:
        hotel += 1
    else:
        centro_comercial += 1

# %%
labels = ['Proyecto hotel', 'Proyecto centro comercial']
sizes = [hotel, centro_comercial]
colors = ['yellowgreen', 'lightskyblue']
patches = plt.pie(sizes, colors=colors, shadow=True, startangle=90, autopct='%1.1f%%', labels=labels)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### 1000 iteraciones

# %%
N = 1000

# %%
hotel = 0
centro_comercial = 0
for i in range(N):
    valor_presente_hotel = 0
    for i in range(len(proyecto_hotel)):
        c = proyecto_hotel[i][2](proyecto_hotel[i][0], proyecto_hotel[i][1])
        valor_presente_hotel += vpn(c, i, r)

    valor_presente_centrocomercial = 0
    for i in range(len(proyecto_centrocomercial)):
        c = proyecto_centrocomercial[i][2](proyecto_centrocomercial[i][0], proyecto_centrocomercial[i][1])
        valor_presente_centrocomercial += vpn(c, i, r)

    if valor_presente_hotel > valor_presente_centrocomercial:
        hotel += 1
    else:
        centro_comercial += 1

# %%
labels = ['Proyecto hotel', 'Proyecto centro comercial']
sizes = [hotel, centro_comercial]
colors = ['yellowgreen', 'lightskyblue']
patches = plt.pie(sizes, colors=colors, shadow=True, startangle=90, autopct='%1.1f%%', labels=labels)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### 10000 iteraciones

# %%
N = 100000

# %%
hotel = 0
centro_comercial = 0
for i in range(N):
    valor_presente_hotel = 0
    for i in range(len(proyecto_hotel)):
        c = proyecto_hotel[i][2](proyecto_hotel[i][0], proyecto_hotel[i][1])
        valor_presente_hotel += vpn(c, i, r)

    valor_presente_centrocomercial = 0
    for i in range(len(proyecto_centrocomercial)):
        c = proyecto_centrocomercial[i][2](proyecto_centrocomercial[i][0], proyecto_centrocomercial[i][1])
        valor_presente_centrocomercial += vpn(c, i, r)

    if valor_presente_hotel > valor_presente_centrocomercial:
        hotel += 1
    else:
        centro_comercial += 1

# %%
labels = ['Proyecto hotel', 'Proyecto centro comercial']
sizes = [hotel, centro_comercial]
colors = ['yellowgreen', 'lightskyblue']
patches = plt.pie(sizes, colors=colors, shadow=True, startangle=90, autopct='%1.1f%%', labels=labels)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Ejercicio 4- Repartidor de periódicos

# %%
import numpy
import random
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1 Mes

# %%
#Variables
it = 30
prob9, prob10, prob11 = 0.3, 0.4, 0.3
gananciaTotal9, gananciaTotal10, gananciaTotal11 = 0,0,0
y9, y10, y11 = [], [], []
x = []

# %%
for j in range (0,it):
    probDiaria = random.random()
    #Solo vendo 9 periodicos
    if (probDiaria<=prob9):
        gananciaTotal9 += 9
        gananciaTotal10 += 8
        gananciaTotal11 += 7
    #Solo vendo 10 periodicos
    elif(probDiaria>prob9 and probDiaria<=(prob9+prob10)):
        gananciaTotal9 += 9
        gananciaTotal10 += 10
        gananciaTotal11 += 9
    #Solo vendo 11 periodicos
    elif(probDiaria>(prob9+prob10)):
        gananciaTotal9 += 9
        gananciaTotal10 += 10
        gananciaTotal11 += 11
    
    x.append(j)
    y9.append(gananciaTotal9)
    y10.append(gananciaTotal10)
    y11.append(gananciaTotal11)

plt.scatter(x, y9, s=0.3, edgecolor = 'blue')
plt.scatter(x, y10, s=0.3, edgecolor = 'green')
plt.scatter(x, y11, s=0.3, edgecolor = 'yellow')
plt.plot(x, y9, 'b')
plt.plot(x, y10, 'g')
plt.plot(x, y11, 'y')
plt.show()

# %% [markdown]
# ### 1 Año

# %%
#Variables
it = 365
prob9, prob10, prob11 = 0.3, 0.4, 0.3
gananciaTotal9, gananciaTotal10, gananciaTotal11 = 0,0,0
y9, y10, y11 = [], [], []
x = []

# %%
for j in range (0,it):
    probDiaria = random.random()
    #Solo vendo 9 periodicos
    if (probDiaria<=prob9):
        gananciaTotal9 += 9
        gananciaTotal10 += 8
        gananciaTotal11 += 7
    #Solo vendo 10 periodicos
    elif(probDiaria>prob9 and probDiaria<=(prob9+prob10)):
        gananciaTotal9 += 9
        gananciaTotal10 += 10
        gananciaTotal11 += 9
    #Solo vendo 11 periodicos
    elif(probDiaria>(prob9+prob10)):
        gananciaTotal9 += 9
        gananciaTotal10 += 10
        gananciaTotal11 += 11
    
    x.append(j)
    y9.append(gananciaTotal9)
    y10.append(gananciaTotal10)
    y11.append(gananciaTotal11)

plt.scatter(x, y9, s=0.3, edgecolor = 'blue')
plt.scatter(x, y10, s=0.3, edgecolor = 'green')
plt.scatter(x, y11, s=0.3, edgecolor = 'yellow')
plt.plot(x, y9, 'b')
plt.plot(x, y10, 'g')
plt.plot(x, y11, 'y')
plt.show()

# %% [markdown]
# ### 10 Años

# %%
#Variables
it = 3650
prob9, prob10, prob11 = 0.3, 0.4, 0.3
gananciaTotal9, gananciaTotal10, gananciaTotal11 = 0,0,0
y9, y10, y11 = [], [], []
x = []

# %%
for j in range (0,it):
    probDiaria = random.random()
    #Solo vendo 9 periodicos
    if (probDiaria<=prob9):
        gananciaTotal9 += 9
        gananciaTotal10 += 8
        gananciaTotal11 += 7
    #Solo vendo 10 periodicos
    elif(probDiaria>prob9 and probDiaria<=(prob9+prob10)):
        gananciaTotal9 += 9
        gananciaTotal10 += 10
        gananciaTotal11 += 9
    #Solo vendo 11 periodicos
    elif(probDiaria>(prob9+prob10)):
        gananciaTotal9 += 9
        gananciaTotal10 += 10
        gananciaTotal11 += 11
    
    x.append(j)
    y9.append(gananciaTotal9)
    y10.append(gananciaTotal10)
    y11.append(gananciaTotal11)

plt.scatter(x, y9, s=0.3, edgecolor = 'blue')
plt.scatter(x, y10, s=0.3, edgecolor = 'green')
plt.scatter(x, y11, s=0.3, edgecolor = 'yellow')
plt.plot(x, y9, 'b')
plt.plot(x, y10, 'g')
plt.plot(x, y11, 'y')
plt.show()

# %% [markdown]
# Finalmente podemos concluir que siempre termina mejor el de 10 periódicos. Dado que en todas las gráficas, ya sea un mes, un año o diez años siempre generan mayor ganancia y es porque el de 9 periódicos es como "una ganancia fija" el de 10 periódicos tiene una probabilidad de 70%, dado que es la probabilidad de comprar 10 u 11 periódicos en un día.
